# %% [markdown]
# # Books Recommender Engine: Preprocessing and Content Recommender

# %% [markdown]
# - [The Error](#The-Error)

# %% [markdown]
# ### Contents:
# - [Imports](#Imports)
# - [Reading in the Data](#Reading-in-the-Data)
# - [Preprocessing](#Preprocessing)
# - [Recommender](#Recommender)
# - [Evaluating the Recommender](#Evalutating-the-Recommender)

# %% [markdown]
# ## Imports

# %%
#importing the packages
import pandas as pd
import sys
from scipy import sparse 
from sklearn.metrics.pairwise import pairwise_distances, cosine_similarity

# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## Preprocessing

# %%
#reading in the data
goodreads_sample = pd.read_csv('./datasets/goodreads_sample.csv')
#dropping the unnamed columns
goodreads_sample.drop(columns='Unnamed: 0', inplace = True)
#checking out the file
goodreads_sample.head()
# Out:
#             author_name  book_average_rating  \
# 0        Carolyn Keene                  4.24
# 1           C.S. Lewis                  4.12
# 2          Paul Zindel                  3.59
# 3           Paul Scott                  4.48
# 4  Catherine Christian                  3.96
#
#                                           book_title          genre_1  \
# 0                        Nancy Drew: #1-6 [Box Set]           Mystery
# 1         Space Trilogy: Out of the Silent Planet...  Science Fiction
# 2                                        The Pigman           Fiction
# 3              Raj Quartet-4v-Boxed Jewell in Crown           Fiction
# 4                                     The Pendragon         Mythology
#
#        genre_2  num_ratings  num_reviews  pages  publish_date  score
# 0  Young Adult         2883          108      0          1930   2937
# 1      Fiction         8258          358      0          1938   1706
# 2  Young Adult        24602         1328      0          1968   3447
# 3     Cultural          861           67      0          1976   3981
# 4      Fantasy          373           24      0          1979  14141

# %% [markdown]
# I need to drop columns I won't be using for the recommender. Based on how many authors and categories there are, I believe there will be too many dummy fields in a pivot table. So I'm going to start with genre_1 and test that first and drop the others for now.

# %%
#
goodreads_sample.drop(['author_name', 'genre_2'], 1,  inplace=True)

# %%
#setting the titles to the index
goodreads_sample.set_index('book_title', inplace = True)

# %%
goodreads_sample.head()
# Out:
#                                                     book_average_rating  \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                  4.24
#        Space Trilogy: Out of the Silent Planet ...                 4.12
#        The Pigman                                                  3.59
#        Raj Quartet-4v-Boxed Jewell in Crown                        4.48
#        The Pendragon                                               3.96
#
#                                                             genre_1  \
# book_title
#        Nancy Drew: #1-6 [Box Set]                           Mystery
#        Space Trilogy: Out of the Silent Planet ...  Science Fiction
#        The Pigman                                           Fiction
#        Raj Quartet-4v-Boxed Jewell in Crown                 Fiction
#        The Pendragon                                      Mythology
#
#                                                     num_ratings  num_reviews  \
# book_title
#        Nancy Drew: #1-6 [Box Set]                          2883          108
#        Space Trilogy: Out of the Silent Planet ...         8258          358
#        The Pigman                                         24602         1328
#        Raj Quartet-4v-Boxed Jewell in Crown                 861           67
#        The Pendragon                                        373           24
#
#                                                     pages  publish_date  score
# book_title
#        Nancy Drew: #1-6 [Box Set]                       0          1930   2937
#        Space Trilogy: Out of the Silent Planet ...      0          1938   1706
#        The Pigman                                       0          1968   3447
#        Raj Quartet-4v-Boxed Jewell in Crown             0          1976   3981
#        The Pendragon                                    0          1979  14141

# %%
#turning genre_1 into dummies
goodreads_dummies = pd.get_dummies(goodreads_sample, columns=['genre_1'], drop_first=True)

# %%
goodreads_dummies.head()
# Out:
#                                                     book_average_rating  \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                  4.24
#        Space Trilogy: Out of the Silent Planet ...                 4.12
#        The Pigman                                                  3.59
#        Raj Quartet-4v-Boxed Jewell in Crown                        4.48
#        The Pendragon                                               3.96
#
#                                                     num_ratings  num_reviews  \
# book_title
#        Nancy Drew: #1-6 [Box Set]                          2883          108
#        Space Trilogy: Out of the Silent Planet ...         8258          358
#        The Pigman                                         24602         1328
#        Raj Quartet-4v-Boxed Jewell in Crown                 861           67
#        The Pendragon                                        373           24
#
#                                                     pages  publish_date  \
# book_title
#        Nancy Drew: #1-6 [Box Set]                       0          1930
#        Space Trilogy: Out of the Silent Planet ...      0          1938
#        The Pigman                                       0          1968
#        Raj Quartet-4v-Boxed Jewell in Crown             0          1976
#        The Pendragon                                    0          1979
#
#                                                     score  \
# book_title
#        Nancy Drew: #1-6 [Box Set]                    2937
#        Space Trilogy: Out of the Silent Planet ...   1706
#        The Pigman                                    3447
#        Raj Quartet-4v-Boxed Jewell in Crown          3981
#        The Pendragon                                14141
#
#                                                     genre_1_Adult Fiction  \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                       0
#        Space Trilogy: Out of the Silent Planet ...                      0
#        The Pigman                                                       0
#        Raj Quartet-4v-Boxed Jewell in Crown                             0
#        The Pendragon                                                    0
#
#                                                     genre_1_Adventure  \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                   0
#        Space Trilogy: Out of the Silent Planet ...                  0
#        The Pigman                                                   0
#        Raj Quartet-4v-Boxed Jewell in Crown                         0
#        The Pendragon                                                0
#
#                                                     genre_1_Amish  \
# book_title
#        Nancy Drew: #1-6 [Box Set]                               0
#        Space Trilogy: Out of the Silent Planet ...              0
#        The Pigman                                               0
#        Raj Quartet-4v-Boxed Jewell in Crown                     0
#        The Pendragon                                            0
#
#                                                     genre_1_Animals  ...  \
# book_title                                                           ...
#        Nancy Drew: #1-6 [Box Set]                                 0  ...
#        Space Trilogy: Out of the Silent Planet ...                0  ...
#        The Pigman                                                 0  ...
#        Raj Quartet-4v-Boxed Jewell in Crown                       0  ...
#        The Pendragon                                              0  ...
#
#                                                     genre_1_Travel  \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                0
#        Space Trilogy: Out of the Silent Planet ...               0
#        The Pigman                                                0
#        Raj Quartet-4v-Boxed Jewell in Crown                      0
#        The Pendragon                                             0
#
#                                                     genre_1_Unfinished  \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                    0
#        Space Trilogy: Out of the Silent Planet ...                   0
#        The Pigman                                                    0
#        Raj Quartet-4v-Boxed Jewell in Crown                          0
#        The Pendragon                                                 0
#
#                                                     genre_1_United States  \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                       0
#        Space Trilogy: Out of the Silent Planet ...                      0
#        The Pigman                                                       0
#        Raj Quartet-4v-Boxed Jewell in Crown                             0
#        The Pendragon                                                    0
#
#                                                     genre_1_War  \
# book_title
#        Nancy Drew: #1-6 [Box Set]                             0
#        Space Trilogy: Out of the Silent Planet ...            0
#        The Pigman                                             0
#        Raj Quartet-4v-Boxed Jewell in Crown                   0
#        The Pendragon                                          0
#
#                                                     genre_1_Warfare  \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                 0
#        Space Trilogy: Out of the Silent Planet ...                0
#        The Pigman                                                 0
#        Raj Quartet-4v-Boxed Jewell in Crown                       0
#        The Pendragon                                              0
#
#                                                     genre_1_Westerns  \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                  0
#        Space Trilogy: Out of the Silent Planet ...                 0
#        The Pigman                                                  0
#        Raj Quartet-4v-Boxed Jewell in Crown                        0
#        The Pendragon                                               0
#
#                                                     genre_1_Womens Fiction  \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                        0
#        Space Trilogy: Out of the Silent Planet ...                       0
#        The Pigman                                                        0
#        Raj Quartet-4v-Boxed Jewell in Crown                              0
#        The Pendragon                                                     0
#
#                                                     genre_1_World War II  \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                      0
#        Space Trilogy: Out of the Silent Planet ...                     0
#        The Pigman                                                      0
#        Raj Quartet-4v-Boxed Jewell in Crown                            0
#        The Pendragon                                                   0
#
#                                                     genre_1_Writing  \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                 0
#        Space Trilogy: Out of the Silent Planet ...                0
#        The Pigman                                                 0
#        Raj Quartet-4v-Boxed Jewell in Crown                       0
#        The Pendragon                                              0
#
#                                                     genre_1_Young Adult
# book_title
#        Nancy Drew: #1-6 [Box Set]                                     0
#        Space Trilogy: Out of the Silent Planet ...                    0
#        The Pigman                                                     0
#        Raj Quartet-4v-Boxed Jewell in Crown                           0
#        The Pendragon                                                  0
#
# [5 rows x 126 columns]

# %% [markdown]
# ## Recommender
#
# Something about how I couldn't do a pivot table for this one because of volume of columns so I went direct to cosine similarity.

# %%
#setting up the recommender 
recommender = cosine_similarity(goodreads_dummies.iloc[:,:])

# %%
#verifying the shape of the engine to make sure the numbers are the same
recommender.shape
# Out:
# (21487, 21487)

# %%
#creating a dataframe to bring the title names back into view
recommender_df = pd.DataFrame(recommender, columns=goodreads_dummies.index, index=goodreads_dummies.index)
recommender_df.head(3)
# Out:
# book_title                                                 Nancy Drew: #1-6 [Box Set]   \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                             1.000000
#        Space Trilogy: Out of the Silent Planet ...                            0.827883
#        The Pigman                                                             0.749036
#
# book_title                                                 Space Trilogy: Out of the Silent Planet / Perelandra / That Hideous Strength   \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                                            0.827883
#        Space Trilogy: Out of the Silent Planet ...                                           1.000000
#        The Pigman                                                                            0.987174
#
# book_title                                                 The Pigman   \
# book_title
#        Nancy Drew: #1-6 [Box Set]                             0.749036
#        Space Trilogy: Out of the Silent Planet ...            0.987174
#        The Pigman                                             1.000000
#
# book_title                                                 Raj Quartet-4v-Boxed Jewell in Crown   \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                                       0.874143
#        Space Trilogy: Out of the Silent Planet ...                                      0.452859
#        The Pigman                                                                       0.344132
#
# book_title                                                 The Pendragon   \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                0.714890
#        Space Trilogy: Out of the Silent Planet ...               0.251017
#        The Pigman                                                0.173505
#
# book_title                                                 House on Mango Street   \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                        0.645240
#        Space Trilogy: Out of the Silent Planet ...                       0.958874
#        The Pigman                                                        0.988866
#
# book_title                                                 Baby-Sitters Club Boxed Set #1   \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                                 0.822424
#        Space Trilogy: Out of the Silent Planet ...                                0.989643
#        The Pigman                                                                 0.961473
#
# book_title                                                 Baby-Sitters Club Boxed Set #1   \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                                 0.894445
#        Space Trilogy: Out of the Silent Planet ...                                0.988292
#        The Pigman                                                                 0.952079
#
# book_title                                                 The Clan of the Cave Bear, the Valley of Horses, the Mammoth Hunters, the Plains of Passage   \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                                            0.811121
#        Space Trilogy: Out of the Silent Planet ...                                           0.984200
#        The Pigman                                                                            0.954264
#
# book_title                                                 The Clan of the Cave Bear, the Valley of Horses, the Mammoth Hunters, the Plains of Passage   \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                                            0.823193
#        Space Trilogy: Out of the Silent Planet ...                                           0.986008
#        The Pigman                                                                            0.954860
#
# book_title                                          ...  \
# book_title                                          ...
#        Nancy Drew: #1-6 [Box Set]                   ...
#        Space Trilogy: Out of the Silent Planet ...  ...
#        The Pigman                                   ...
#
# book_title                                                 The Second World War   \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                       0.412825
#        Space Trilogy: Out of the Silent Planet ...                      0.385163
#        The Pigman                                                       0.336067
#
# book_title                                                 The Second World War   \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                       0.646630
#        Space Trilogy: Out of the Silent Planet ...                      0.413053
#        The Pigman                                                       0.344565
#
# book_title                                                 The Second World War   \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                       0.629695
#        Space Trilogy: Out of the Silent Planet ...                      0.414455
#        The Pigman                                                       0.347201
#
# book_title                                                 Pandora   \
# book_title
#        Nancy Drew: #1-6 [Box Set]                          0.278614
#        Space Trilogy: Out of the Silent Planet ...         0.184436
#        The Pigman                                          0.127419
#
# book_title                                                 Pandora   \
# book_title
#        Nancy Drew: #1-6 [Box Set]                          0.238524
#        Space Trilogy: Out of the Silent Planet ...         0.172674
#        The Pigman                                          0.119164
#
# book_title                                                 The Complete Aubrey/Maturin Novels (5 Volumes)   \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                                            0.341433
#        Space Trilogy: Out of the Silent Planet ...                                           0.267043
#        The Pigman                                                                            0.222291
#
# book_title                                                 Worm   \
# book_title
#        Nancy Drew: #1-6 [Box Set]                       0.566352
#        Space Trilogy: Out of the Silent Planet ...      0.599353
#        The Pigman                                       0.571006
#
# book_title                                                 Worm   \
# book_title
#        Nancy Drew: #1-6 [Box Set]                       0.469355
#        Space Trilogy: Out of the Silent Planet ...      0.578487
#        The Pigman                                       0.559481
#
# book_title                                                 Frog and Toad Together   \
# book_title
#        Nancy Drew: #1-6 [Box Set]                                         0.710558
#        Space Trilogy: Out of the Silent Planet ...                        0.978302
#        The Pigman                                                         0.997660
#
# book_title                                                 Songs from the Phenomenal Nothing
# book_title
#        Nancy Drew: #1-6 [Box Set]                                                    0.784855
#        Space Trilogy: Out of the Silent Planet ...                                   0.325851
#        The Pigman                                                                    0.187054
#
# [3 rows x 21487 columns]

# %% [markdown]
# ## The Error

# %% [markdown]
# ## Evaluation of the Recommender Engine

# %%
#this is code to help find how the title is listed, adjusting the head value will give you more listed options
#if there are any, which there can be especially with foreign versions of titles
q = 'The Pendragon'
goodreads_sample[goodreads_sample['book_title'].str.contains(q)]['book_title'].head(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'book_title'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-106-3434ba06ca4e> in <module>
#       2 #if there are any, which there can be especially with foreign versions of titles
#       3 q = 'The Pendragon'
# ----> 4 goodreads[goodreads['book_title'].str.contains(q)]['book_title'].head(1)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
# -> 2658                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2659         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2660         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'book_title'

# %%
#Looking up recommendations for those who liked The Pendragon:
recommender_df['The Pendragon'].sort_values()[1:11]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# KeyError: 'The Pendragon'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-e031a7efd1f1> in <module>
#       1 #Looking up recommendations for those who liked The Lovely Bones:
# ----> 2 recommender_df['The Pendragon'].sort_values()[1:11]
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
# -> 2658                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2659         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2660         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# KeyError: 'The Pendragon'
