# %% [markdown]
# <img src="./assets/bookstack.jpg" style="float: left; margin: 20px; height: 100px">
#
# # Book Recommender Engines Capstone Project<br><br>Content-Based: Preprocessing and Engine<br>
# ***

# %% [markdown]
# ### Contents:
# - [Imports](#Imports)
# - [Reading in the Data](#Reading-in-the-Data)
# - [Preprocessing](#Preprocessing)
# - [Recommender](#Recommender)
# - [Evaluating the Recommender](#Evalutating-the-Recommender)

# %% [markdown]
# ## Imports

# %%
#importing the packages
import pandas as pd
import sys
from scipy import sparse 
from sklearn.metrics.pairwise import pairwise_distances, cosine_similarity

# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## Preprocessing

# %%
#reading in the data
goodreads_sample = pd.read_csv('./datasets/goodreads_sample.csv')
#dropping the unnamed columns
goodreads_sample.drop(columns='Unnamed: 0', inplace = True)
#checking out the file
goodreads_sample.head()
# Out:
#      author_name  book_average_rating  \
# 0   J.K. Rowling                 4.56
# 1   J.K. Rowling                 4.48
# 2   J.K. Rowling                 4.55
# 3  Douglas Adams                 4.38
# 4    Bill Bryson                 4.20
#
#                                       book_title          genre_1  \
# 0         Harry Potter and the Half-Blood Prince          Fantasy
# 1      Harry Potter and the Order of the Phoenix          Fantasy
# 2       Harry Potter and the Prisoner of Azkaban          Fantasy
# 3  The Ultimate Hitchhiker's Guide to the Galaxy  Science Fiction
# 4           A Short History of Nearly Everything       Nonfiction
#
#        genre_2  num_ratings  num_reviews  pages  publish_date  score
# 0  Young Adult      2036961        32557    652          2005   1217
# 1  Young Adult      2087093        34321    870          2003    690
# 2  Young Adult      2276977        44377    435          1999    368
# 3      Fiction       255070         4753    815          1996   2374
# 4      Science       240843        10362    544          2003   1079

# %% [markdown]
# I need to drop columns I won't be using for the recommender. Based on how many authors and categories there are, I believe there will be too many dummy fields in a pivot table. So I'm going to start with genre_1 and test that first and drop the others for now.

# %%
#Dropping author name and genre_2 because I believe it will be to much data to make them into dummies
#But I will come back and reassess after I get a working engine
#goodreads_sample.drop(['author_name', 'genre_2'], 1,  inplace=True)
goodreads_sample.drop(['num_reviews', 'book_average_rating'], 1,  inplace=True)

# %%
#setting the titles to the index
goodreads_sample.set_index('book_title', inplace = True)

# %%
goodreads_sample.head()
# Out:
#                                                  author_name          genre_1  \
# book_title
# Harry Potter and the Half-Blood Prince          J.K. Rowling          Fantasy
# Harry Potter and the Order of the Phoenix       J.K. Rowling          Fantasy
# Harry Potter and the Prisoner of Azkaban        J.K. Rowling          Fantasy
# The Ultimate Hitchhiker's Guide to the Galaxy  Douglas Adams  Science Fiction
# A Short History of Nearly Everything             Bill Bryson       Nonfiction
#
#                                                    genre_2  num_ratings  \
# book_title
# Harry Potter and the Half-Blood Prince         Young Adult      2036961
# Harry Potter and the Order of the Phoenix      Young Adult      2087093
# Harry Potter and the Prisoner of Azkaban       Young Adult      2276977
# The Ultimate Hitchhiker's Guide to the Galaxy      Fiction       255070
# A Short History of Nearly Everything               Science       240843
#
#                                                pages  publish_date  score
# book_title
# Harry Potter and the Half-Blood Prince           652          2005   1217
# Harry Potter and the Order of the Phoenix        870          2003    690
# Harry Potter and the Prisoner of Azkaban         435          1999    368
# The Ultimate Hitchhiker's Guide to the Galaxy    815          1996   2374
# A Short History of Nearly Everything             544          2003   1079

# %%
#turning genre_1 into dummies
goodreads_dummies = pd.get_dummies(goodreads_sample, columns=['author_name', 'genre_1', 'genre_2'], drop_first=True)

# The Ultimate Hitchhiker's Guide to the Galaxy            0                0
# A Short History of Nearly Everything                     0                0
#
#                                                genre_2_Westerns  \
# book_title
# Harry Potter and the Half-Blood Prince                        0
# Harry Potter and the Order of the Phoenix                     0
# Harry Potter and the Prisoner of Azkaban                      0
# The Ultimate Hitchhiker's Guide to the Galaxy                 0
# A Short History of Nearly Everything                          0
#
#                                                genre_2_Womens Fiction  \
# book_title
# Harry Potter and the Half-Blood Prince                              0
# Harry Potter and the Order of the Phoenix                           0
# Harry Potter and the Prisoner of Azkaban                            0
# The Ultimate Hitchhiker's Guide to the Galaxy                       0
# A Short History of Nearly Everything                                0
#
#                                                genre_2_World War II  \
# book_title
# Harry Potter and the Half-Blood Prince                            0
# Harry Potter and the Order of the Phoenix                         0
# Harry Potter and the Prisoner of Azkaban                          0
# The Ultimate Hitchhiker's Guide to the Galaxy                     0
# A Short History of Nearly Everything                              0
#
#                                                genre_2_Writing  \
# book_title
# Harry Potter and the Half-Blood Prince                       0
# Harry Potter and the Order of the Phoenix                    0
# Harry Potter and the Prisoner of Azkaban                     0
# The Ultimate Hitchhiker's Guide to the Galaxy                0
# A Short History of Nearly Everything                         0
#
#                                                genre_2_Young Adult
# book_title
# Harry Potter and the Half-Blood Prince                           1
# Harry Potter and the Order of the Phoenix                        1
# Harry Potter and the Prisoner of Azkaban                         1
# The Ultimate Hitchhiker's Guide to the Galaxy                    0
# A Short History of Nearly Everything                             0
#
# [5 rows x 11339 columns]

# %% [markdown]
# ## Recommender
#
# Something about how I couldn't do a pivot table for this one because of volume of columns so I went direct to cosine similarity.

# %%
#setting up the recommender 
recommender = cosine_similarity(goodreads_dummies.iloc[:,:])

# %%
#verifying the shape of the engine to make sure the numbers are the same
recommender.shape
# Out:
# (15144, 15144)

# %%
#creating a dataframe to bring the title names back into view
recommender_df = pd.DataFrame(recommender, columns=goodreads_dummies.index, index=goodreads_dummies.index)
recommender_df.head(3)
# Out:
# book_title                                 Harry Potter and the Half-Blood Prince  \
# book_title
# Harry Potter and the Half-Blood Prince                                        1.0
# Harry Potter and the Order of the Phoenix                                     1.0
# Harry Potter and the Prisoner of Azkaban                                      1.0
#
# book_title                                 Harry Potter and the Order of the Phoenix  \
# book_title
# Harry Potter and the Half-Blood Prince                                           1.0
# Harry Potter and the Order of the Phoenix                                        1.0
# Harry Potter and the Prisoner of Azkaban                                         1.0
#
# book_title                                 Harry Potter and the Prisoner of Azkaban  \
# book_title
# Harry Potter and the Half-Blood Prince                                          1.0
# Harry Potter and the Order of the Phoenix                                       1.0
# Harry Potter and the Prisoner of Azkaban                                        1.0
#
# book_title                                 The Ultimate Hitchhiker's Guide to the Galaxy  \
# book_title
# Harry Potter and the Half-Blood Prince                                          0.999935
# Harry Potter and the Order of the Phoenix                                       0.999932
# Harry Potter and the Prisoner of Azkaban                                        0.999930
#
# book_title                                 A Short History of Nearly Everything  \
# book_title
# Harry Potter and the Half-Blood Prince                                 0.999964
# Harry Potter and the Order of the Phoenix                              0.999963
# Harry Potter and the Prisoner of Azkaban                               0.999961
#
# book_title                                 Notes from a Small Island  \
# book_title
# Harry Potter and the Half-Blood Prince                      0.999307
# Harry Potter and the Order of the Phoenix                   0.999299
# Harry Potter and the Prisoner of Azkaban                    0.999291
#
# book_title                                 The Mother Tongue: English and How It Got That Way  \
# book_title
# Harry Potter and the Half-Blood Prince                                              0.988661
# Harry Potter and the Order of the Phoenix                                           0.988624
# Harry Potter and the Prisoner of Azkaban                                            0.988594
#
# book_title                                  Hatchet  Changeling  \
# book_title
# Harry Potter and the Half-Blood Prince     0.999897    0.247019
# Harry Potter and the Order of the Phoenix  0.999893    0.246790
# Harry Potter and the Prisoner of Azkaban   0.999890    0.246595
#
# book_title                                 The Known World  ...  \
# book_title                                                  ...
# Harry Potter and the Half-Blood Prince            0.997949  ...
# Harry Potter and the Order of the Phoenix         0.997946  ...
# Harry Potter and the Prisoner of Azkaban          0.997935  ...
#
# book_title                                 Save Me from Myself  \
# book_title
# Harry Potter and the Half-Blood Prince                0.141250
# Harry Potter and the Order of the Phoenix             0.141014
# Harry Potter and the Prisoner of Azkaban              0.140811
#
# book_title                                 Somewhere on Maui  Dead by Morning  \
# book_title
# Harry Potter and the Half-Blood Prince              0.039270         0.089500
# Harry Potter and the Order of the Phoenix           0.039015         0.089382
# Harry Potter and the Prisoner of Azkaban            0.038821         0.089196
#
# book_title                                 Jade City  Grasping at Eternity  \
# book_title
# Harry Potter and the Half-Blood Prince      0.807403              0.629421
# Harry Potter and the Order of the Phoenix   0.807330              0.629278
# Harry Potter and the Prisoner of Azkaban    0.807214              0.629122
#
# book_title                                 If I Let You Go  Becoming Human  \
# book_title
# Harry Potter and the Half-Blood Prince            0.267568        0.596655
# Harry Potter and the Order of the Phoenix         0.267378        0.596502
# Harry Potter and the Prisoner of Azkaban          0.267202        0.596338
#
# book_title                                 Shanghai Nobody      Slay  \
# book_title
# Harry Potter and the Half-Blood Prince            0.031374  0.008376
# Harry Potter and the Order of the Phoenix         0.031297  0.008236
# Harry Potter and the Prisoner of Azkaban          0.031158  0.008049
#
# book_title                                 The Baghdad Clock
# book_title
# Harry Potter and the Half-Blood Prince              0.302195
# Harry Potter and the Order of the Phoenix           0.301964
# Harry Potter and the Prisoner of Azkaban            0.301773
#
# [3 rows x 15144 columns]

# %% [markdown]
# ## Evaluation of the Recommender Engine

# %%
#reading in the data
find_title = pd.read_csv('./datasets/goodreads_sample.csv')
#dropping the unnamed columns
find_title.drop(columns='Unnamed: 0', inplace = True)

# %%
#this is code to help find how the title is listed, adjusting the head value will give you more listed options
#if there are any, which there can be especially with foreign versions of titles
q = 'Lovely Bones'
find_title[find_title['book_title'].str.contains(q)]['book_title'].head()
# Out:
# 7605    The Lovely Bones
# Name: book_title, dtype: object

# %%
#Looking up recommendations for those who liked The Pendragon:
recommender_df['Harry Potter and the Half-Blood Prince'].sort_values(ascending=False)[1:11]
# Out:
# book_title
# Mockingjay                                   1.0
# The Help                                     1.0
# The Lovely Bones                             1.0
# The Da Vinci Code                            1.0
# Harry Potter and the Order of the Phoenix    1.0
# Angels & Demons                              1.0
# The Girl on the Train                        1.0
# Animal Farm                                  1.0
# The Girl with the Dragon Tattoo              1.0
# Gone Girl                                    1.0
# Name: Harry Potter and the Half-Blood Prince, dtype: float64

# %%
#Looking up recommendations for those who liked The Lovely Bones:
recommender_df['The Lovely Bones'].sort_values(ascending=False)[1:11]
# Out:
# book_title
# Mockingjay                                1.0
# The Help                                  1.0
# The Da Vinci Code                         1.0
# Harry Potter and the Half-Blood Prince    1.0
# The Girl on the Train                     1.0
# The Giver                                 1.0
# Animal Farm                               1.0
# The Book Thief                            1.0
# Angels & Demons                           1.0
# Memoirs of a Geisha                       1.0
# Name: The Lovely Bones, dtype: float64
